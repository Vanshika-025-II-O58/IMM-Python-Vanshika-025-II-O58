# %%
#introduction

# %%
print("Hello World") #prints hello world
# Out:
# Hello World

# %%
print(2+3) #addition
# Out:
# 5

# %%
print(3-1) #subtraction
# Out:
# 2

# %%
print(2*3) #multiplication
# Out:
# 6

# %%
print(3/2) #division
# Out:
# 1.5

# %%
print(3**2) #exponential
# Out:
# 9

# %%
print(3%2) #modulus returns remainder
# Out:
# 1

# %%
print(7//3) #Floor division operator: returns quotient
# Out:
# 2

# %%
#Data Types

print(type(10))    #int
print(type(3.14))    #float
print(type(1+3j))    #complex
print(type('Vanshika'))  #String
print(type([1,2,3]))    #list
print(type({'name': 'Vanshika'}))    #dictionary
print(type({9.8,3.14,2.7}) )   #tuple
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>
# <class 'set'>

# %%
#difference between list and tuple: Lists are mutable and can be modified while Tuples are immutable and cannot be modified.

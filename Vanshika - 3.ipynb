# %%
language = 'Python'
second_letter = language[1]
print(second_letter) # y
last_index = len(language) - 1
last_letter = language[last_index]
print(last_letter) # n
# If we want to start from right end we can use negative indexing. -1 is the last index
last_letter = language[-1]
print(last_letter) # n
second_last = language[-2]
print(second_last) # o
# Out:
# y
# n
# n
# o

# %%
# Slicing
language = 'Python'
# starts at zero index and up to 3 but not include 3
first_three = language[0:3]
last_three = language[3:6]
print(last_three) # hon
# Another way
last_three = language[-3:]
print(last_three) # hon
last_three = language [3:]
print(last_three) # hon
# Out:
# hon
# hon
# hon

# %%
# Skipping character while splitting Python strings
language = 'Python'
pto = language[0:6:2]
print(pto) # pto
# Out:
# Pto

# %%
# Escape sequence
print('l hope every one enjoying the python challenge. \nDo you ?') # line break
print('Days\tTopics\tExercises')
print('Day 1\t3\t5')
print('Day 2 t3 t5')
print('Day 3 t3 \t5')
print('Day 4\t3 t5' )
print('This is a back slash symbol \\') # To write a back slash print In every programming language it starts with | "Hello, World!\'')
# Out:
# l hope every one enjoying the python challenge.
# Do you ?
# Days	Topics	Exercises
# Day 1	3	5
# Day 2 t3 t5
# Day 3 t3 	5
# Day 4	3 t5
# This is a back slash symbol \

# %%
# String Methods
# capitalize(): Converts the first character the string to Capital Letter
challenge = 'python programming'
print(challenge.capitalize()) #'python programming'
#count(): returns occurrences of substring in string, count(substring, start=.., end=..)
challenge = 'python programming'
print(challenge.count('p')) # 2
print(challenge.count('p', 7, 14)) #1
print(challenge.count('th')) # 2
# endswith(): Checks if a string ends with a specified ending
challenge = 'python programming'
print(challenge.endswith('ing')) # True
print(challenge.endswith('tion')) # False
# expandtabs): Replaces tab character with spaces, default tab size is 8. It takes tab size argument
challenge = 'python\tprogramming'
print(challenge.expandtabs(10)) #'python programming' print(challenge.expandtabs(10)) # 'python programming'
# find(): Returns the index of first occurrence of substring
challenge = 'python programming'
print(challenge.find('o')) #4
print(challenge.find('th')) #2
# Out:
# Python programming
# 2
# 1
# 1
# True
# False
# python    programming
# 4
# 2

# %%
# format() formats string into nicer output
first_name = 'Vanshika'
last_name = 'K'
job = 'student'
country = 'India'
sentence = 'I am {fn} {ln}. I am a {occ}. I live in {place}.'.format(fn = first_name,ln = last_name, occ = job, place = country)
print(sentence)
radius = 1
pi = 3.14
area = pi*(radius**2)
result = 'The area of circle with radius {} is {}'.format(str(radius), str(area))
print(result) # The area of circle with 10 is 314.0
# index): Returns the index of substring
challenge = 'python programming'
print(challenge.find('y')) #5
print(challenge.find('th')) #0
# isalnum(): Checks alphanumeric character
challenge = 'pythonprogramming'
print(challenge.isalnum()) # True
# Out:
# I am Vanshika K. I am a student. I live in India.
# The area of circle with radius 1 is 3.14
# 1
# 2
# True

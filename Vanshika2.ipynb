# %%
#variables in python

first_name = 'Vanshika'
last_name = 'K'
country = 'India'
city = 'Lucknow'
age = 24
is_married = False
skills = ['HTML','CSS','JS','Python','MySQL']
person_info = { 'firstname': 'Vanshika',
                'lastname': 'K',
                'country': 'India',
                'city': 'Delhi'
              }

# %%
print(skills[3])
# Out:
# Python
